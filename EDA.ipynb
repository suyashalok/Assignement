# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Suyash/OneDrive/Documents/creditcard.csv")
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
##Checking the shape of the dataset

# %%
df.shape
# Out:
# (284807, 31)

# %%
# Check for null values

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Descriptive statistics of the dataset

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
#Key Takeaways:
# 1. Class Imbalance: Only 0.17% of transactions are fraudulent, requiring techniques like oversampling or undersampling to address the imbalance.
# 2. Transaction Amounts: The Amount feature is highly skewed with a median of $22 and a maximum of $25,691, suggesting the need for scaling or transformation.
# 3. PCA Features: V1 to V28 are standardized with means near 0 but exhibit wide ranges, indicating potential outliers or significant variation.
# 4. Time: Transactions span about two days, but Time does not directly correlate with fraud.

# %%
# DATA CLEANING

# %%
missing_values = df.isnull().sum()

# Filtering to show only columns with missing values, if any
columns_with_missing_values = missing_values[missing_values > 0]
columns_with_missing_values
# Out:
# Series([], dtype: int64)

# %%
print(df.columns.tolist())
# Out:
# ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']

# %%
# Handling Null Values:

#For this dataset, there is no need to fill any missing values as there are no null values present. However, in cases where null values are found, several methods can be used to handle them effectively:

# 1. Dropping Null Values:
# dropna(axis=0): Removes rows with null values.
# dropna(axis=1): Removes columns with null values.

# 2.Filling Null Values with a Specific Value:
#fillna(value): Replaces all null values with a specified value such as 0, a constant, or any other value.

# 3. Filling Nulls with Statistical Measures (e.g., Mean, Median):
# fillna(df.mean()): Fills null values with the mean of the respective column.
# fillna(df.median()): Fills null values with the median of the respective column.

# %%
# Column Names:

# There is no need to change the names of the columns in this dataset as they are already appropriately labeled. However, if you need to rename columns, you can use the rename() function:

# df.rename(columns={'old_name': 'new_name'}): Renames specified columns, where 'old_name' is the current column name and 'new_name' is the desired new name.

# %%
# Data Transformation

# %%
df['NormalizedAmount'] = (df['Amount'] - df['Amount'].mean()) / df['Amount'].std()
print(df)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V22       V23  \
# ...

# %%
# Mathematical Transformation

# %%
df['AmountLog'] = np.log(df['Amount'] + 1)
print(df)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V23       V24  \
# ...

# %%
# "Adding a new column 'Fraud' where 99% of transactions are labeled as True Positive (1) and the remaining as False Positive (0), based on the reviewer's assessment."

# %%
df['Fraud'] = np.random.choice([0, 1], size=len(df), p=[0.99, 0.01])

# %%
#File Conversion:

# %%
df.to_parquet('transformed_data.parquet')

# %%
# SQL querying

# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V24       V25       V26       V27       V28  \
# ...

# %%
conn = sqlite3.connect(':memory:')

# %%
df.to_sql('transformed_data', conn, index=False, if_exists='replace')
# Out:
# 284807

# %%
query1 = """
SELECT AVG(NormalizedAmount) AS avg_normalized_amount_fraudulent
FROM transformed_data
WHERE Fraud = 1;
"""
result1 = pd.read_sql_query(query1, conn)

# %%
query2 = """
SELECT MAX(NormalizedAmount) AS max_normalized_amount_non_fraudulent
FROM transformed_data
WHERE Fraud = 0;
"""
result2 = pd.read_sql_query(query2, conn)

# %%
query3 = """
SELECT 
    Fraud, 
    AVG(AmountLog) AS avg_amount_log
FROM transformed_data
GROUP BY Fraud;
"""
result3 = pd.read_sql_query(query3, conn)

# %%
print("Average Normalized Amount in Fraudulent Transactions:")
print(result1)
print("\nMaximum Normalized Amount in Non-Fraudulent Transactions:")
print(result2)
print("\nAverage AmountLog for Fraudulent and Non-Fraudulent Transactions:")
print(result3)
# Out:
# Average Normalized Amount in Fraudulent Transactions:
#    avg_normalized_amount_fraudulent
# 0                         -0.009787
#
# Maximum Normalized Amount in Non-Fraudulent Transactions:
#    max_normalized_amount_non_fraudulent
# 0                            102.362063
#
# Average AmountLog for Fraudulent and Non-Fraudulent Transactions:
#    Fraud  avg_amount_log
# 0      0        3.152013
# 1      1        3.169465

# %%
conn.close()
